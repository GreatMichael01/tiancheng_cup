# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %% [markdown]
# ### 读取operation_train_new，和operation_round1_new数据

# %%
operation_train_new = pd.read_csv("../data/operation_train_new.csv")
operation_round1_new = pd.read_csv("../data/operation_round1_new.csv")
operation = pd.concat([operation_train_new, operation_round1_new], axis=0)

# %% [markdown]
# ### 对operation_train_new数据的时间进行处理

# %%
operation["time"] = operation["time"].fillna(value="00:00:00")
operation["hour"] = operation.time.apply(lambda  x: x.split(":")[0]).astype(int)
operation["minutes"] = operation.time.apply(lambda  x: x.split(":")[1]).astype(int)

# %%
operation.shape

# %% [markdown]
# ### 对数据one-hot

# %%
operation = operation.drop(["time"], axis=1)
feature = operation.columns.drop(["UID"])

print("one-hot...")
for col in feature:
    lbl = preprocessing.LabelEncoder()
    operation[col] = lbl.fit_transform(list(operation[col].values))

# %% [markdown]
# ## 对operation_new数据开发新特征

# %%
operation_new = operation
gby=operation_new.loc[:,['UID', 'day', 'mode', 'success', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code', 
                   'ip1_sub', 'ip2_sub', 'hour', 'minutes']].groupby(["UID"],as_index=False)

operation_new_sum = gby.sum()
operation_new_sum.columns = ['UID', 'day_sum', 'mode_sum', 'success_sum', 'os_sum', 'version_sum', 'device1_sum',
                         'device2_sum', 'device_code1_sum', 'device_code2_sum', 'device_code3_sum', 'mac1_sum',
                         'mac2_sum', 'ip1_sum', 'ip2_sum', 'wifi_sum', 'geo_code_sum', 'ip1_sub_sum', 'ip2_sub_sum',
                         'hour_sum', 'minutes_sum']
data1=pd.merge(operation_new, operation_new_sum, how='left', on = "UID")

operation_new_count = gby.count()
operation_new_count.columns = ['UID', 'day_count', 'mode_count', 'success_count', 'os_count', 'version_count', 'device1_count',
                         'device2_count', 'device_code1_count', 'device_code2_count', 'device_code3_count', 'mac1_count',
                         'mac2_count', 'ip1_count', 'ip2_count', 'wifi_count', 'geo_code_count', 'ip1_sub_count', 'ip2_sub_count',
                         'hour_count', 'minutes_count']
data1 = pd.merge(data1, operation_new_count, how="left", on="UID")

operation_new_max = gby.max()
operation_new_max.columns = ['UID', 'day_max', 'mode_max', 'success_max', 'os_max', 'version_max', 'device1_max',
                         'device2_max', 'device_code1_max', 'device_code2_max', 'device_code3_max', 'mac1_max',
                         'mac2_max', 'ip1_max', 'ip2_max', 'wifi_max', 'geo_code_max', 'ip1_sub_max', 'ip2_sub_max',
                         'hour_max', 'minutes_max']
data1 = pd.merge(data1, operation_new_max, how="left", on="UID")

operation_new_min = gby.min()
operation_new_min.columns = ['UID', 'day_min', 'mode_min', 'success_min', 'os_min', 'version_min', 'device1_min',
                         'device2_min', 'device_code1_min', 'device_code2_min', 'device_code3_min', 'mac1_min',
                         'mac2_min', 'ip1_min', 'ip2_min', 'wifi_min', 'geo_code_min', 'ip1_sub_min', 'ip2_sub_min',
                         'hour_min', 'minutes_min']
data1 = pd.merge(data1, operation_new_min, how="left", on="UID")

operation_new_mean = gby.mean()
operation_new_mean.columns = ['UID', 'day_mean', 'mode_mean', 'success_mean', 'os_mean', 'version_mean', 'device1_mean',
                         'device2_mean', 'device_code1_mean', 'device_code2_mean', 'device_code3_mean', 'mac1_mean',
                         'mac2_mean', 'ip1_mean', 'ip2_mean', 'wifi_mean', 'geo_code_mean', 'ip1_sub_mean', 'ip2_sub_mean',
                         'hour_mean', 'minutes_mean']
data1 = pd.merge(data1, operation_new_mean, how="left", on="UID")

operation_new_median = gby.median()
operation_new_median.columns = ['UID', 'day_median', 'mode_median', 'success_median', 'os_median', 'version_median', 'device1_median',
                         'device2_median', 'device_code1_median', 'device_code2_median', 'device_code3_median', 'mac1_median',
                         'mac2_median', 'ip1_median', 'ip2_median', 'wifi_median', 'geo_code_median', 'ip1_sub_median', 'ip2_sub_median',
                         'hour_median', 'minutes_median']
data1 = pd.merge(data1, operation_new_median, how="left", on="UID")

operation_new_std = gby.std()
operation_new_std.columns = ['UID', 'day_std', 'mode_std', 'success_std', 'os_std', 'version_std', 'device1_std',
                         'device2_std', 'device_code1_std', 'device_code2_std', 'device_code3_std', 'mac1_std',
                         'mac2_std', 'ip1_std', 'ip2_std', 'wifi_std', 'geo_code_std', 'ip1_sub_std', 'ip2_sub_std',
                         'hour_std', 'minutes_std']
data1 = pd.merge(data1, operation_new_std, how="left", on="UID")

operation_new_var = gby.var()
operation_new_var.columns = ['UID', 'day_var', 'mode_var', 'success_var', 'os_var', 'version_var', 'device1_var',
                         'device2_var', 'device_code1_var', 'device_code2_var', 'device_code3_var', 'mac1_var',
                         'mac2_var', 'ip1_var', 'ip2_var', 'wifi_var', 'geo_code_var', 'ip1_sub_var', 'ip2_sub_var',
                         'hour_var', 'minutes_var']
data1 = pd.merge(data1, operation_new_var, how="left", on="UID")

# %%
data1 = data1.drop_duplicates("UID",keep="last")

# %%
data1.shape

# %% [markdown]
# ### 对operation_new补充新特征

# %%
dup_opera_new = operation_new.drop_duplicates("UID")

# %%
dup_opera_new.shape

# %%
# 同一用户在同一天内操作的数据信息

operation_new = operation
daygby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code', 
                   'ip1_sub', 'ip2_sub']].groupby(["day"],as_index=False)
dayoperation_new_count = daygby.count()
dayoperation_new_count.columns = ['UID', 'day_day_count',  'day_os_count', 'day_version_count', 'day_device1_count',
                                  'day_device2_count', 'day_device_code1_count', 'day_device_code2_count', 'day_device_code3_count',
                                  'day_mac1_count','day_mac2_count', 'day_ip1_count', 'day_ip2_count', 'day_wifi_count', 
                                  'day_geo_code_count','day_ip1_sub_count','day_ip2_sub_count']
data1_1 = pd.merge(data1, dayoperation_new_count, how="left", on="UID")

mac1gby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code', 
                   'ip1_sub', 'ip2_sub']].groupby(["mac1"],as_index=False)
mac1operation_new_count = mac1gby.count()
mac1operation_new_count.columns = ['UID', 'mac1_day_count',  'mac1_os_count', 'mac1_version_count', 'mac1_device1_count',
                                  'mac1_device2_count', 'mac1_device_code1_count', 'mac1_device_code2_count', 'mac1_device_code3_count',
                                  'mac1_mac1_count','mac1_mac2_count', 'mac1_ip1_count', 'mac1_ip2_count', 'mac1_wifi_count', 
                                  'mac1_geo_code_count','mac1_ip1_sub_count','mac1_ip2_sub_count']
data1_2 = pd.merge(data1_1, mac1operation_new_count, how="left", on="UID")

ip1gby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code', 
                   'ip1_sub', 'ip2_sub']].groupby(["ip1"],as_index=False)
ip1operation_new_count = ip1gby.count()
ip1operation_new_count.columns = ['UID', 'ip1_day_count',  'ip1_os_count', 'ip1_version_count', 'ip1_device1_count',
                                  'ip1_device2_count', 'ip1_device_code1_count', 'ip1_device_code2_count', 'ip1_device_code3_count',
                                  'ip1_mac1_count','ip1_mac2_count', 'ip1_ip1_count', 'ip1_ip2_count', 'ip1_wifi_count', 
                                  'ip1_geo_code_count','ip1_ip1_sub_count','ip1_ip2_sub_count']
data1_3 = pd.merge(data1_2, ip1operation_new_count, how="left", on="UID")

mac2gby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code', 
                   'ip1_sub', 'ip2_sub']].groupby(["mac2"],as_index=False)
mac2operation_new_count = mac2gby.count()
mac2operation_new_count.columns = ['UID', 'mac2_day_count',  'mac2_os_count', 'mac2_version_count', 'mac2_device1_count',
                                  'mac2_device2_count', 'mac2_device_code1_count', 'mac2_device_code2_count', 'mac2_device_code3_count',
                                  'mac2_mac1_count','mac2_mac2_count', 'mac2_ip1_count', 'mac2_ip2_count', 'mac2_wifi_count', 
                                  'mac2_geo_code_count','mac2_ip1_sub_count','mac2_ip2_sub_count']
data1_4 = pd.merge(data1_3, mac2operation_new_count, how="left", on="UID")

ip2gby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code', 
                   'ip1_sub', 'ip2_sub']].groupby(["ip2"],as_index=False)
ip2operation_new_count = ip2gby.count()
ip2operation_new_count.columns = ['UID', 'ip2_day_count',  'ip2_os_count', 'ip2_version_count', 'ip2_device1_count',
                                  'ip2_device2_count', 'ip2_device_code1_count', 'ip2_device_code2_count', 'ip2_device_code3_count',
                                  'ip2_mac1_count','ip2_mac2_count', 'ip2_ip1_count', 'ip2_ip2_count', 'ip2_wifi_count', 
                                  'ip2_geo_code_count','ip2_ip1_sub_count','ip2_ip2_sub_count']
data1_5 = pd.merge(data1_4, ip2operation_new_count, how="left", on="UID")

wifigby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code',
                   'ip1_sub', 'ip2_sub']].groupby(["wifi"],as_index=False)
wifioperation_new_count = wifigby.count()
wifioperation_new_count.columns = ['UID', 'wifi_day_count',  'wifi_os_count', 'wifi_version_count', 'wifi_device1_count',
                                  'wifi_device2_count', 'wifi_device_code1_count', 'wifi_device_code2_count', 'wifi_device_code3_count',
                                  'wifi_mac1_count','wifi_mac2_count', 'wifi_ip1_count', 'wifi_ip2_count', 'wifi_wifi_count',
                                  'wifi_geo_code_count','wifi_ip1_sub_count','wifi_ip2_sub_count']
data1_6 = pd.merge(data1_5, wifioperation_new_count, how="left", on="UID")

geo_codegby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code',
                   'ip1_sub', 'ip2_sub']].groupby(["geo_code"],as_index=False)
geo_codeoperation_new_count = geo_codegby.count()
geo_codeoperation_new_count.columns = ['UID', 'geo_code_day_count',  'geo_code_os_count', 'geo_code_version_count', 'geo_code_device1_count',
                                  'geo_code_device2_count', 'geo_code_device_code1_count', 'geo_code_device_code2_count', 'geo_code_device_code3_count',
                                  'geo_code_mac1_count','geo_code_mac2_count', 'geo_code_ip1_count', 'geo_code_ip2_count', 'geo_code_wifi_count',
                                  'geo_code_geo_code_count','geo_code_ip1_sub_count','geo_code_ip2_sub_count']
data1_7 = pd.merge(data1_6, geo_codeoperation_new_count, how="left", on="UID")

ip1_subgby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code',
                   'ip1_sub', 'ip2_sub']].groupby(["ip1_sub"],as_index=False)
ip1_suboperation_new_count = ip1_subgby.count()
ip1_suboperation_new_count.columns = ['UID', 'ip1_sub_day_count',  'ip1_sub_os_count', 'ip1_sub_version_count', 'ip1_sub_device1_count',
                                  'ip1_sub_device2_count', 'ip1_sub_device_code1_count', 'ip1_sub_device_code2_count', 'ip1_sub_device_code3_count',
                                  'ip1_sub_mac1_count','ip1_sub_mac2_count', 'ip1_sub_ip1_count', 'ip1_sub_ip2_count', 'ip1_sub_wifi_count',
                                  'ip1_sub_geo_code_count','ip1_sub_ip1_sub_count','ip1_sub_ip2_sub_count']
data1_8 = pd.merge(data1_7, ip1_suboperation_new_count, how="left", on="UID")

ip2_subgby=operation.loc[:,['UID', 'day', 'os', 'version','device1', 'device2', 'device_code1', 'device_code2',
                   'device_code3', 'mac1', 'mac2', 'ip1', 'ip2', 'wifi','geo_code',
                   'ip1_sub', 'ip2_sub']].groupby(["ip2_sub"],as_index=False)
ip2_suboperation_new_count = ip2_subgby.count()
ip2_suboperation_new_count.columns = ['UID', 'ip2_sub_day_count',  'ip2_sub_os_count', 'ip2_sub_version_count', 'ip2_sub_device1_count',
                                  'ip2_sub_device2_count', 'ip2_sub_device_code1_count', 'ip2_sub_device_code2_count', 'ip2_sub_device_code3_count',
                                  'ip2_sub_mac1_count','ip2_sub_mac2_count', 'ip2_sub_ip1_count', 'ip2_sub_ip2_count', 'ip2_sub_wifi_count',
                                  'ip2_sub_geo_code_count','ip2_sub_ip1_sub_count','ip2_sub_ip2_sub_count']
data1_9 = pd.merge(data1_8, ip2_suboperation_new_count, how="left", on="UID")

# %%
data1_9.shape

# %%
del data1

# %% [markdown]
# ## 读取transaction_train_new，和transaction_round1_new数据集

# %%
transaction_train_new = pd.read_csv("../data/transaction_train_new.csv")
transaction_round1_new = pd.read_csv("../data/transaction_round1_new.csv")
transaction = pd.concat([transaction_train_new, transaction_round1_new], axis=0)

# %%
transaction.shape

# %% [markdown]
# ### 对transaction_train_new数据进行时间处理

# %%
transaction["time"] = transaction["time"].fillna(value="00:00:00")
transaction["hour"] = transaction.time.apply(lambda  x: x.split(":")[0]).astype(int)
transaction["minutes"] = transaction.time.apply(lambda  x: x.split(":")[1]).astype(int)

# %%
transaction.shape

# %% [markdown]
# ### 对数据one-hot

# %%
transaction = transaction.drop(["time"], axis=1)
feature = transaction.columns.drop(["UID"])
con_feature = ["bal", "trans_amt"]
dis_feature = feature.drop(con_feature)

print("one-hot...")
for col in dis_feature:
    lbl = preprocessing.LabelEncoder()
    transaction[col] = lbl.fit_transform(list(transaction[col].values))

# %%
dup_trans_new_UID = pd.DataFrame(transaction.drop_duplicates("UID").UID)

# %%
transaction_new = transaction
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1', 
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub', 'hour', 'minutes']].groupby(["UID"],as_index=False)

transaction_new_sum = gby.sum()
transaction_new_sum.columns = ['UID', 'channel_sum', 'day_sum', 'trans_amt_sum', 'amt_src1_sum', 'merchant_sum', 'code1_sum', 
                               'code2_sum', 'trans_type1_sum', 'acc_id1_sum', 'device_code1_sum', 'device_code2_sum', 
                               'device_code3_sum', 'device1_sum', 'device2_sum', 'mac1_sum', 'ip1_sum', 'bal_sum', 'amt_src2_sum',
                               'acc_id2_sum', 'acc_id3_sum', 'geo_code_sum', 'trans_type2_sum', 'market_code_sum', 'market_type_sum', 
                               'p1_sub_sum', 'hour_sum', 'minutes_sum']
data2=pd.merge(transaction_new, transaction_new_sum, how='left', on = "UID")

transaction_count = gby.count()
transaction_count.columns = ['UID', 'channel_count', 'day_count', 'trans_amt_count', 'amt_src1_count', 'merchant_count', 'code1_count', 
                               'code2_count', 'trans_type1_count', 'acc_id1_count', 'device_code1_count', 'device_code2_count', 
                               'device_code3_count', 'device1_count', 'device2_count', 'mac1_count', 'ip1_count', 'bal_count', 'amt_src2_count',
                               'acc_id2_count', 'acc_id3_count', 'geo_code_count', 'trans_type2_count', 'market_code_count', 'market_type_count', 
                               'p1_sub_count', 'hour_count', 'minutes_count']
data2=pd.merge(data2, transaction_count, how='left', on = "UID")

transaction_max = gby.max()
transaction_max.columns = ['UID', 'channel_max', 'day_max', 'trans_amt_max', 'amt_src1_max', 'merchant_max', 'code1_max', 
                               'code2_max', 'trans_type1_max', 'acc_id1_max', 'device_code1_max', 'device_code2_max', 
                               'device_code3_max', 'device1_max', 'device2_max', 'mac1_max', 'ip1_max', 'bal_max', 'amt_src2_max',
                               'acc_id2_max', 'acc_id3_max', 'geo_code_max', 'trans_type2_max', 'market_code_max', 'market_type_max', 
                               'p1_sub_max', 'hour_max', 'minutes_max']
data2=pd.merge(data2, transaction_max, how='left', on = "UID")

transaction_min = gby.min()
transaction_min.columns = ['UID', 'channel_min', 'day_min', 'trans_amt_min', 'amt_src1_min', 'merchant_min', 'code1_min', 
                               'code2_min', 'trans_type1_min', 'acc_id1_min', 'device_code1_min', 'device_code2_min', 
                               'device_code3_min', 'device1_min', 'device2_min', 'mac1_min', 'ip1_min', 'bal_min', 'amt_src2_min',
                               'acc_id2_min', 'acc_id3_min', 'geo_code_min', 'trans_type2_min', 'market_code_min', 'market_type_min', 
                               'p1_sub_min', 'hour_min', 'minutes_min']
data2=pd.merge(data2, transaction_min, how='left', on = "UID")

transaction_mean = gby.mean()
transaction_mean.columns = ['UID', 'channel_mean', 'day_mean', 'trans_amt_mean', 'amt_src1_mean', 'merchant_mean', 'code1_mean', 
                               'code2_mean', 'trans_type1_mean', 'acc_id1_mean', 'device_code1_mean', 'device_code2_mean', 
                               'device_code3_mean', 'device1_mean', 'device2_mean', 'mac1_mean', 'ip1_mean', 'bal_mean', 'amt_src2_mean',
                               'acc_id2_mean', 'acc_id3_mean', 'geo_code_mean', 'trans_type2_mean', 'market_code_mean', 'market_type_mean', 
                               'p1_sub_mean', 'hour_mean', 'minutes_mean']
data2=pd.merge(data2, transaction_mean, how='left', on = "UID")

transaction_median = gby.median()
transaction_median.columns = ['UID', 'channel_median', 'day_median', 'trans_amt_median', 'amt_src1_median', 'merchant_median', 'code1_median', 
                               'code2_median', 'trans_type1_median', 'acc_id1_median', 'device_code1_median', 'device_code2_median', 
                               'device_code3_median', 'device1_median', 'device2_median', 'mac1_median', 'ip1_median', 'bal_median', 'amt_src2_median',
                               'acc_id2_median', 'acc_id3_median', 'geo_code_median', 'trans_type2_median', 'market_code_median', 'market_type_median', 
                               'p1_sub_median', 'hour_median', 'minutes_median']
data2=pd.merge(data2, transaction_median, how='left', on = "UID")

transaction_std = gby.std()
transaction_std.columns = ['UID', 'channel_std', 'day_std', 'trans_amt_std', 'amt_src1_std', 'merchant_std', 'code1_std', 
                               'code2_std', 'trans_type1_std', 'acc_id1_std', 'device_code1_std', 'device_code2_std', 
                               'device_code3_std', 'device1_std', 'device2_std', 'mac1_std', 'ip1_std', 'bal_std', 'amt_src2_std',
                               'acc_id2_std', 'acc_id3_std', 'geo_code_std', 'trans_type2_std', 'market_code_std', 'market_type_std', 
                               'p1_sub_std', 'hour_std', 'minutes_std']
data2=pd.merge(data2, transaction_std, how='left', on = "UID")

transaction_var = gby.var()
transaction_var.columns = ['UID', 'channel_var', 'day_var', 'trans_amt_var', 'amt_src1_var', 'merchant_var', 'code1_var', 
                               'code2_var', 'trans_type1_var', 'acc_id1_var', 'device_code1_var', 'device_code2_var', 
                               'device_code3_var', 'device1_var', 'device2_var', 'mac1_var', 'ip1_var', 'bal_var', 'amt_src2_var',
                               'acc_id2_var', 'acc_id3_var', 'geo_code_var', 'trans_type2_var', 'market_code_var', 'market_type_var', 
                               'p1_sub_var', 'hour_var', 'minutes_var']
data2=pd.merge(data2, transaction_var, how='left', on = "UID")

# %%
data2 = data2.drop_duplicates("UID", keep="last")

# %%
data2.shape

# %% [markdown]
# ### 对transaction_new补充特征

# %%
transaction_new = transaction
dup_trans_new = transaction_new.drop_duplicates("UID")

# %%
dup_trans_new.shape

# %%
# 同一用户在同一天内操作的数据信息
transaction_new = transaction
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1', 
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["day"],as_index=False)

daytransaction_new_count = gby.count()
daytransaction_new_count.columns = ['UID','day_channel_count', 'day_day_count',  'day_trans_amt_count', 'day_amt_src1_count', 'day_merchant_count',
                                    'day_code1_count','day_code2_count', 'day_trans_type1_count', 'day_acc_id1_count','day_device_code1_count',
                                    'day_device_code2_count','day_device_code3_count', 'day_device1_count', 'day_device2_count', 
                                    'day_mac1_count','day_ip1_count','day_bal_count', 'day_amt_src2_count', 'day_acc_id2_count', 
                                    'day_acc_id3_count', 'day_geo_code_count', 'day_trans_type2_count', 'day_market_code_count',
                                    'day_market_type_count', 'day_ip1_sub_count']
data2_1=pd.merge(data2, daytransaction_new_count, how='left', on = "UID")

# 同一用户相同mac1操作的数据信息
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1', 
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["mac1"],as_index=False)

mac1transaction_new_count = gby.count()
mac1transaction_new_count.columns = ['UID','mac1_channel_count', 'mac1_day_count',  'mac1_trans_amt_count', 'mac1_amt_src1_count', 'mac1_merchant_count',
                                    'mac1_code1_count','mac1_code2_count', 'mac1_trans_type1_count', 'mac1_acc_id1_count','mac1_device_code1_count',
                                    'mac1_device_code2_count','mac1_device_code3_count', 'mac1_device1_count', 'mac1_device2_count', 
                                    'mac1_mac1_count','mac1_ip1_count','mac1_bal_count', 'mac1_amt_src2_count', 'mac1_acc_id2_count', 
                                    'mac1_acc_id3_count', 'mac1_geo_code_count', 'mac1_trans_type2_count', 'mac1_market_code_count',
                                    'mac1_market_type_count', 'mac1_ip1_sub_count']
data2_2=pd.merge(data2_1, mac1transaction_new_count, how='left', on = "UID")

# 同一用户在同一天内操作的数据信息
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1', 
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["ip1"],as_index=False)

ip1transaction_new_count = gby.count()
ip1transaction_new_count.columns = ['UID','ip1_channel_count', 'ip1_day_count',  'ip1_trans_amt_count', 'ip1_amt_src1_count', 'ip1_merchant_count',
                                    'ip1_code1_count','ip1_code2_count', 'ip1_trans_type1_count', 'ip1_acc_id1_count','ip1_device_code1_count',
                                    'ip1_device_code2_count','ip1_device_code3_count', 'ip1_device1_count', 'ip1_device2_count', 
                                    'ip1_mac1_count','ip1_ip1_count','ip1_bal_count', 'ip1_amt_src2_count', 'ip1_acc_id2_count', 
                                    'ip1_acc_id3_count', 'ip1_geo_code_count', 'ip1_trans_type2_count', 'ip1_market_code_count',
                                    'ip1_market_type_count', 'ip1_ip1_sub_count']
data2_3=pd.merge(data2_2, ip1transaction_new_count, how='left', on = "UID")


# 同一用户在同一天内操作的数据信息
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1', 
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["acc_id1"],as_index=False)

acc_id1transaction_new_count = gby.count()
acc_id1transaction_new_count.columns = ['UID','acc_id1_channel_count', 'acc_id1_day_count',  'acc_id1_trans_amt_count', 'acc_id1_amt_src1_count', 'acc_id1_merchant_count',
                                    'acc_id1_code1_count','acc_id1_code2_count', 'acc_id1_trans_type1_count', 'acc_id1_acc_id1_count','acc_id1_device_code1_count',
                                    'acc_id1_device_code2_count','acc_id1_device_code3_count', 'acc_id1_device1_count', 'acc_id1_device2_count', 
                                    'acc_id1_mac1_count','acc_id1_ip1_count','acc_id1_bal_count', 'acc_id1_amt_src2_count', 'acc_id1_acc_id2_count', 
                                    'acc_id1_acc_id3_count', 'acc_id1_geo_code_count', 'acc_id1_trans_type2_count', 'acc_id1_market_code_count',
                                    'acc_id1_market_type_count', 'acc_id1_ip1_sub_count']
data2_4=pd.merge(data2_3, acc_id1transaction_new_count, how='left', on = "UID")

# 同一用户在同一天内操作的数据信息
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1',
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["acc_id2"],as_index=False)

acc_id2transaction_new_count = gby.count()
acc_id2transaction_new_count.columns = ['UID','acc_id2_channel_count', 'acc_id2_day_count',  'acc_id2_trans_amt_count', 'acc_id2_amt_src1_count', 'acc_id2_merchant_count',
                                    'acc_id2_code1_count','acc_id2_code2_count', 'acc_id2_trans_type1_count', 'acc_id2_acc_id1_count','acc_id2_device_code1_count',
                                    'acc_id2_device_code2_count','acc_id2_device_code3_count', 'acc_id2_device1_count', 'acc_id2_device2_count',
                                    'acc_id2_mac1_count','acc_id2_ip1_count','acc_id2_bal_count', 'acc_id2_amt_src2_count', 'acc_id2_acc_id2_count',
                                    'acc_id2_acc_id3_count', 'acc_id2_geo_code_count', 'acc_id2_trans_type2_count', 'acc_id2_market_code_count',
                                    'acc_id2_market_type_count', 'acc_id2_ip1_sub_count']
data2_5=pd.merge(data2_4, acc_id2transaction_new_count, how='left', on = "UID")

# 同一用户在同一天内操作的数据信息
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1',
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["acc_id3"],as_index=False)

acc_id3transaction_new_count = gby.count()
acc_id3transaction_new_count.columns = ['UID','acc_id3_channel_count', 'acc_id3_day_count',  'acc_id3_trans_amt_count', 'acc_id3_amt_src1_count', 'acc_id3_merchant_count',
                                    'acc_id3_code1_count','acc_id3_code2_count', 'acc_id3_trans_type1_count', 'acc_id3_acc_id1_count','acc_id3_device_code1_count',
                                    'acc_id3_device_code2_count','acc_id3_device_code3_count', 'acc_id3_device1_count', 'acc_id3_device2_count',
                                    'acc_id3_mac1_count','acc_id3_ip1_count','acc_id3_bal_count', 'acc_id3_amt_src2_count', 'acc_id3_acc_id2_count',
                                    'acc_id3_acc_id3_count', 'acc_id3_geo_code_count', 'acc_id3_trans_type2_count', 'acc_id3_market_code_count',
                                    'acc_id3_market_type_count', 'acc_id3_ip1_sub_count']
data2_6=pd.merge(data2_5, acc_id3transaction_new_count, how='left', on = "UID")

# 同一用户在同一天内操作的数据信息
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1',
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["geo_code"],as_index=False)

geo_codetransaction_new_count = gby.count()
geo_codetransaction_new_count.columns = ['UID','geo_code_channel_count', 'geo_code_day_count',  'geo_code_trans_amt_count', 'geo_code_amt_src1_count', 'geo_code_merchant_count',
                                    'geo_code_code1_count','geo_code_code2_count', 'geo_code_trans_type1_count', 'geo_code_acc_id1_count','geo_code_device_code1_count',
                                    'geo_code_device_code2_count','geo_code_device_code3_count', 'geo_code_device1_count', 'geo_code_device2_count',
                                    'geo_code_mac1_count','geo_code_ip1_count','geo_code_bal_count', 'geo_code_amt_src2_count', 'geo_code_acc_id2_count',
                                    'geo_code_acc_id3_count', 'geo_code_geo_code_count', 'geo_code_trans_type2_count', 'geo_code_market_code_count',
                                    'geo_code_market_type_count', 'geo_code_ip1_sub_count']
data2_7=pd.merge(data2_6, geo_codetransaction_new_count, how='left', on = "UID")

# 同一用户在同一天内操作的数据信息
gby=transaction_new.loc[:,['UID', 'channel', 'day', 'trans_amt', 'amt_src1', 'merchant', 'code1', 'code2', 'trans_type1',
                           'acc_id1', 'device_code1', 'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1', 
                           'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2', 'market_code', 'market_type', 
                           'ip1_sub']].groupby(["ip1_sub"],as_index=False)

ip1_subtransaction_new_count = gby.count()
ip1_subtransaction_new_count.columns = ['UID','ip1_sub_channel_count', 'ip1_sub_day_count',  'ip1_sub_trans_amt_count', 'ip1_sub_amt_src1_count', 'ip1_sub_merchant_count',
                                    'ip1_sub_code1_count','ip1_sub_code2_count', 'ip1_sub_trans_type1_count', 'ip1_sub_acc_id1_count','ip1_sub_device_code1_count',
                                    'ip1_sub_device_code2_count','ip1_sub_device_code3_count', 'ip1_sub_device1_count', 'ip1_sub_device2_count',
                                    'ip1_sub_mac1_count','ip1_sub_ip1_count','ip1_sub_bal_count', 'ip1_sub_amt_src2_count', 'ip1_sub_acc_id2_count',
                                    'ip1_sub_acc_id3_count', 'ip1_sub_geo_code_count', 'ip1_sub_trans_type2_count', 'ip1_sub_market_code_count',
                                    'ip1_sub_market_type_count', 'ip1_sub_ip1_sub_count']
data2_8=pd.merge(data2_7, ip1_subtransaction_new_count, how='left', on = "UID")

# %%
data2_8.shape

# %%
tag_train_new = pd.read_csv("../data/tag_train_new.csv")

# %% [markdown]
# ### 给test制作标签，加以区分train和test

# %%
operation_round1_new = operation_round1_new.drop_duplicates(["UID"], keep="last")
transaction_round1_new = transaction_round1_new.drop_duplicates(["UID"], keep="last")
test_C = pd.merge(operation_round1_new, transaction_round1_new, on="UID", how="outer")
prob_sample = pd.DataFrame({"UID": test_C.UID, "Tag": -1})

# %%
data = pd.merge(data1_9, data2_8, how="outer", on="UID").drop_duplicates("UID")
data["day_maxy-minx"] = data["day_max_y"] - data["day_min_x"]
data["day_vary-varx"] = data["day_var_y"] - data["day_var_x"]

# %% [markdown]
# ### 获得train数据集

# %%
train = pd.merge(data, tag_train_new, how="inner", on="UID")
train = train.sort_values("UID")

# %%
train.shape

# %% [markdown]
# ### 获得test数据集

# %%
test = pd.merge(data, prob_sample, how="inner", on="UID")
test = test.sort_values("UID")
test = test.drop(["Tag"], axis=1)

# %%
test.shape

# %%
train.to_csv("./data_feat/train.csv", index=False)

# %%
test.to_csv("./data_feat/test.csv", index=False)

# %% [markdown]
# ## 训练模型xgb

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
import time

params = {"booster": "gbtree",
          "objective" : "binary:logistic",
          "eval_metric" : "auc",
          "verbose" : 1, 
          "eta" : 0.01, 
          "max_delta_step" : 5, 
          "max_depth" : 20, 
          "alpha" : 2, 
          "lambda" : 2, 
          "gamma" : 0.5, 
          "subsample" : 0.8, 
          "colsample_bytree" : 0.8, 
#           "colsample_bylevel" : 0.8, 
          "min_child_weight" : 5, 
          "scale_pos_weight" : 0.8,
          "n_jobs" : -1}

train_Y = train.Tag
train_X = train.drop([ "Tag"], axis=1)

x_train, x_val, y_train, y_true = train_test_split(train_X, train_Y, test_size=0.2, random_state=2018)

matrix_train = xgb.DMatrix(x_train, y_train)
matrix_test = xgb.DMatrix(x_val)
a_model = xgb.train(params, matrix_train, num_boost_round=3000)
y_predict = a_model.predict(matrix_test)


d = pd.DataFrame()
d['prob'] = list(y_predict)
d['y'] = list(y_true)
d = d.sort_values(['prob'], ascending=[0])
y = d.y
PosAll = pd.Series(y).value_counts()[1]
NegAll = pd.Series(y).value_counts()[0]
pCumsum = d['y'].cumsum()
nCumsum = np.arange(len(y)) - pCumsum + 1
pCumsumPer = pCumsum / PosAll
nCumsumPer = nCumsum / NegAll
TR1 = pCumsumPer[abs(nCumsumPer-0.001).idxmin()]
TR2 = pCumsumPer[abs(nCumsumPer-0.005).idxmin()]
TR3 = pCumsumPer[abs(nCumsumPer-0.01).idxmin()]

result = 0.4 * TR1 + 0.3 * TR2 + 0.3 * TR3
print("*******************************************************************************************************")
print("result:", result)
print("*******************************************************************************************************")

# %%
import xgboost as xgb
import time
import pandas as pd
train = pd.read_csv("./data_feat/train.csv")
test = pd.read_csv("./data_feat/test.csv")

# params = {"booster": "gbtree",
#           "objective" : "binary:logistic",
#           "eval_metric" : "auc",
#           "verbose" : 1, 
#           "eta" : 0.01, 
#           "max_delta_step" : 5, 
#           "max_depth" : 20, 
#           "alpha" : 10, 
#           "lambda" : 10, 
#           "gamma" : 5, 
#           "subsample" : 0.8, 
#           "colsample_bytree" : 0.8, 
# #           "colsample_bylevel" : 0.8, 
#           "min_child_weight" : 5, 
#           "scale_pos_weight" : 0.8,
#           "n_jobs" : -1}
params = {"booster": "gbtree",
          "objective" : "binary:logistic",
          "eval_metric" : "auc",
          "verbose" : 1,
          "eta" : 0.01,
          "max_delta_step" : 5,
          "max_depth" : 20,
          "alpha" : 10,
          "lambda" : 10,
          "gamma" : 2,
          "subsample" : 0.8,
          "colsample_bylevel" : 0.8,
          "min_child_weight" : 5,
          "scale_pos_weight" : 0.8,
          "n_jobs" : -1}

train_Y = train.Tag
train_X = train.drop([ "Tag"], axis=1)
test_UID = test.UID
test_X = test
train_matrix = xgb.DMatrix(train_X, train_Y)
test_matrix = xgb.DMatrix(test_X)

model = xgb.train(params, train_matrix, num_boost_round=3000)
predict = model.predict(test_matrix)

result = pd.DataFrame({"UID": test_UID, "Tag": predict})
result.to_csv("../submission/"+"result_time"+str(int(time.strftime("%Y%m%d%H%M%S", time.localtime(time.time()))))+".csv", index=False)
# Out:
# [09:23:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=8
# [09:23:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=10
# [09:23:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=12
# [09:23:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=9
# [09:23:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=12
# [09:23:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=11
# [09:23:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 10 pruned nodes, max_depth=9
# [09:23:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 8 pruned nodes, max_depth=12
# [09:23:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=10
# [09:23:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=11
# [09:23:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=9
# [09:23:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 12 pruned nodes, max_depth=11
# [09:23:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=11
# [09:23:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=10
# [09:23:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=10
# [09:23:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=11
# [09:23:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=9
# [09:23:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 8 pruned nodes, max_depth=10
# [09:23:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=10
# [09:23:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=12
# [09:23:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=10
# [09:23:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=10
# [09:23:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=10
# [09:23:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=11
# [09:23:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=10
# [09:23:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=12
# [09:23:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=10
# [09:23:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=10
# [09:23:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=10
# [09:23:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=10
# [09:23:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=12
# [09:23:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=10
# [09:23:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=12
# [09:23:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=12
# [09:23:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 8 pruned nodes, max_depth=12
# [09:23:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 12 pruned nodes, max_depth=11
# [09:23:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=12
# [09:23:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 14 pruned nodes, max_depth=11
# [09:23:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 14 pruned nodes, max_depth=12
# [09:23:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=11
# [09:23:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 8 pruned nodes, max_depth=11
# [09:23:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=12
# [09:23:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=13
# [09:23:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=10
# [09:23:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=10
# [09:23:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 8 pruned nodes, max_depth=11
# [09:23:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 14 pruned nodes, max_depth=10
# [09:23:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=9
# [09:23:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=10
# [09:23:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=10
# [09:23:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=11
# [09:23:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 10 pruned nodes, max_depth=12
# [09:23:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 12 pruned nodes, max_depth=11
# [09:23:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=10
# [09:23:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=11
# [09:23:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=10
# [09:23:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=11
# [09:23:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 14 pruned nodes, max_depth=8
# [09:23:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=8
# [09:23:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=9
# [09:23:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=11
# [09:23:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=10
# [09:23:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=12
# [09:23:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=9
# [09:23:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=13
# [09:23:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 14 pruned nodes, max_depth=12
# [09:23:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 12 pruned nodes, max_depth=10
# [09:23:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=12
# [09:23:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=11
# [09:23:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 8 pruned nodes, max_depth=9
# [09:23:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=12
# [09:23:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=10
# [09:23:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=10
# [09:23:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 18 pruned nodes, max_depth=11
# [09:23:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 10 pruned nodes, max_depth=8
# [09:23:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=11
# [09:23:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=10
# [09:23:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=10
# [09:23:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=11
# [09:23:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=13
# [09:23:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=10
# [09:24:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=12
# [09:24:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=10
# [09:24:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=10
# [09:24:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=11
# [09:24:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=11
# [09:24:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 14 pruned nodes, max_depth=9
# [09:24:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=10
# [09:24:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=12
# [09:24:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 16 pruned nodes, max_depth=12
# [09:24:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 16 pruned nodes, max_depth=12
# [09:24:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 12 pruned nodes, max_depth=11
# [09:24:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=12
# [09:24:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 20 pruned nodes, max_depth=10
# [09:24:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 10 pruned nodes, max_depth=9
# [09:24:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=11
# [09:24:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=10
# [09:24:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=12
# [09:24:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=10
# [09:24:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=10
# [09:24:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 22 pruned nodes, max_depth=10
# [09:24:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 16 pruned nodes, max_depth=9
# [09:24:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 20 pruned nodes, max_depth=10
# [09:24:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=11
# [09:24:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 26 pruned nodes, max_depth=11
# [09:24:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=10
# [09:24:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 12 pruned nodes, max_depth=11
# [09:24:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=10
# [09:24:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=10
# [09:24:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 16 pruned nodes, max_depth=9
# [09:24:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 10 pruned nodes, max_depth=10
# [09:24:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=12
# [09:24:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 8 pruned nodes, max_depth=10
# [09:24:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=9
# [09:24:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=11
# [09:24:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 24 pruned nodes, max_depth=8
# [09:24:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 30 pruned nodes, max_depth=8
# [09:24:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 28 pruned nodes, max_depth=9
# [09:24:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=8
# [09:24:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 28 pruned nodes, max_depth=10
# [09:24:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 14 pruned nodes, max_depth=9
# [09:24:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 18 pruned nodes, max_depth=10
# [09:24:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=10
# [09:24:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 16 pruned nodes, max_depth=9
# [09:24:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 16 pruned nodes, max_depth=13
# [09:24:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 22 pruned nodes, max_depth=8
# [09:24:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 12 pruned nodes, max_depth=11
# [09:24:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=9
# [09:24:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 14 pruned nodes, max_depth=12
# [09:24:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 24 pruned nodes, max_depth=9
# [09:24:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 12 pruned nodes, max_depth=9
# [09:24:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=9
# [09:24:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=12
# [09:24:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=10
# [09:24:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 20 pruned nodes, max_depth=10
# [09:24:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 22 pruned nodes, max_depth=10
# [09:24:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 30 pruned nodes, max_depth=9
# [09:24:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=8
# [09:24:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 10 pruned nodes, max_depth=11
# [09:24:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 12 pruned nodes, max_depth=7
# [09:24:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 16 pruned nodes, max_depth=8
# [09:24:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=10
# [09:24:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=11
# [09:24:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 28 pruned nodes, max_depth=9
# [09:24:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 12 pruned nodes, max_depth=10
# [09:24:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 20 pruned nodes, max_depth=10
# [09:24:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 24 pruned nodes, max_depth=11
# [09:24:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=8
# [09:24:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 26 pruned nodes, max_depth=9
# [09:24:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 16 pruned nodes, max_depth=10
# [09:24:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 16 pruned nodes, max_depth=8
# [09:24:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 26 pruned nodes, max_depth=8
# [09:24:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=12
# [09:24:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 22 pruned nodes, max_depth=9
# [09:24:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=10
# [09:24:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 30 pruned nodes, max_depth=10
# [09:24:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 22 pruned nodes, max_depth=9
# [09:24:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 20 pruned nodes, max_depth=8
# [09:24:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 22 pruned nodes, max_depth=9
# [09:24:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 24 pruned nodes, max_depth=8
# [09:24:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=10
# [09:24:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 20 pruned nodes, max_depth=8
# [09:24:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 14 pruned nodes, max_depth=10
# [09:24:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 24 pruned nodes, max_depth=8
# [09:24:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=10
# [09:24:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 24 pruned nodes, max_depth=10
# [09:24:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 38 pruned nodes, max_depth=9
# [09:24:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 28 pruned nodes, max_depth=8
# [09:24:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 28 pruned nodes, max_depth=8
# [09:24:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 20 pruned nodes, max_depth=10
# [09:24:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 10 pruned nodes, max_depth=8
# [09:24:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 20 pruned nodes, max_depth=9
# [09:24:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 34 pruned nodes, max_depth=10
# [09:24:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=9
# [09:24:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 22 pruned nodes, max_depth=10
# [09:24:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 16 pruned nodes, max_depth=9
# [09:24:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 24 pruned nodes, max_depth=9
# [09:24:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=10
# [09:24:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 24 pruned nodes, max_depth=9
# [09:24:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 22 pruned nodes, max_depth=10
# [09:24:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 20 pruned nodes, max_depth=8
# [09:24:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 26 pruned nodes, max_depth=8
# [09:24:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 24 pruned nodes, max_depth=8
# [09:24:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 28 pruned nodes, max_depth=8
# [09:24:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 16 pruned nodes, max_depth=10
# [09:24:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 24 pruned nodes, max_depth=8
# [09:24:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 34 pruned nodes, max_depth=9
# [09:24:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 28 pruned nodes, max_depth=9
# [09:24:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 32 pruned nodes, max_depth=8
# [09:24:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 26 pruned nodes, max_depth=9
# [09:24:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 30 pruned nodes, max_depth=11
# [09:24:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 42 pruned nodes, max_depth=7
# [09:24:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 22 pruned nodes, max_depth=10
# [09:24:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 20 pruned nodes, max_depth=8
# [09:24:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 28 pruned nodes, max_depth=7
# [09:24:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 20 pruned nodes, max_depth=8
# [09:24:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 22 pruned nodes, max_depth=9
# [09:25:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 26 pruned nodes, max_depth=11
# [09:25:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 34 pruned nodes, max_depth=8
# [09:25:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 30 pruned nodes, max_depth=8
# [09:25:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 22 pruned nodes, max_depth=10
# [09:25:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 26 pruned nodes, max_depth=9
# [09:25:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 20 pruned nodes, max_depth=8
# [09:25:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 26 pruned nodes, max_depth=8
# [09:25:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=7
# [09:25:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 26 pruned nodes, max_depth=8
# [09:25:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 30 pruned nodes, max_depth=9
# [09:25:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 28 pruned nodes, max_depth=8
# [09:25:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 30 pruned nodes, max_depth=6
# [09:25:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=9
# [09:25:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 28 pruned nodes, max_depth=9
# [09:25:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=9
# [09:25:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 22 pruned nodes, max_depth=8
# [09:25:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 26 pruned nodes, max_depth=8
# [09:25:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 28 pruned nodes, max_depth=8
# [09:25:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 32 pruned nodes, max_depth=9
# [09:25:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=9
# [09:25:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 30 pruned nodes, max_depth=7
# [09:25:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 26 pruned nodes, max_depth=7
# [09:25:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 26 pruned nodes, max_depth=6
# [09:25:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 30 pruned nodes, max_depth=9
# [09:25:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 20 pruned nodes, max_depth=9
# [09:25:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 18 pruned nodes, max_depth=9
# [09:25:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 30 pruned nodes, max_depth=8
# [09:25:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 20 pruned nodes, max_depth=9
# [09:25:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 16 pruned nodes, max_depth=9
# [09:25:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 46 pruned nodes, max_depth=7
# [09:25:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 28 pruned nodes, max_depth=7
# [09:25:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=9
# [09:25:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 30 pruned nodes, max_depth=8
# [09:25:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=8
# [09:25:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 26 pruned nodes, max_depth=10
# [09:25:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 32 pruned nodes, max_depth=8
# [09:25:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 22 pruned nodes, max_depth=9
# [09:25:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 28 pruned nodes, max_depth=7
# [09:25:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 32 pruned nodes, max_depth=9
# [09:25:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 28 pruned nodes, max_depth=6
# [09:25:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 32 pruned nodes, max_depth=7
# [09:25:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 24 pruned nodes, max_depth=8
# [09:25:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 22 pruned nodes, max_depth=7
# [09:25:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 34 pruned nodes, max_depth=8
# [09:25:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 38 pruned nodes, max_depth=6
# [09:25:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 28 pruned nodes, max_depth=7
# [09:25:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 26 pruned nodes, max_depth=7
# [09:25:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 32 pruned nodes, max_depth=7
# [09:25:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 26 pruned nodes, max_depth=7
# [09:25:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 34 pruned nodes, max_depth=9
# [09:25:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 20 pruned nodes, max_depth=10
# [09:25:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 28 pruned nodes, max_depth=9
# [09:25:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 30 pruned nodes, max_depth=8
# [09:25:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 20 pruned nodes, max_depth=8
# [09:25:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 36 pruned nodes, max_depth=10
# [09:25:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 22 pruned nodes, max_depth=8
# [09:25:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 32 pruned nodes, max_depth=8
# [09:25:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 32 pruned nodes, max_depth=9
# [09:25:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 26 pruned nodes, max_depth=8
# [09:25:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 20 pruned nodes, max_depth=10
# [09:25:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 30 pruned nodes, max_depth=7
# [09:25:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 30 pruned nodes, max_depth=9
# [09:25:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 24 pruned nodes, max_depth=9
# [09:25:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 24 pruned nodes, max_depth=11
# [09:25:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 34 pruned nodes, max_depth=8
# [09:25:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 28 pruned nodes, max_depth=8
# [09:25:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 26 pruned nodes, max_depth=7
# [09:25:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 26 pruned nodes, max_depth=8
# [09:25:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=8
# [09:25:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 24 pruned nodes, max_depth=7
# [09:25:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 28 pruned nodes, max_depth=9
# [09:25:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 22 pruned nodes, max_depth=9
# [09:25:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 24 pruned nodes, max_depth=9
# [09:25:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 34 pruned nodes, max_depth=8
# [09:25:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 28 pruned nodes, max_depth=7
# [09:25:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=9
# [09:25:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 40 pruned nodes, max_depth=9
# [09:25:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 28 pruned nodes, max_depth=8
# [09:25:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 26 pruned nodes, max_depth=8
# ...
# [09:55:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 30 pruned nodes, max_depth=3
# [09:55:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 32 pruned nodes, max_depth=0
# [09:55:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 46 pruned nodes, max_depth=3
# [09:55:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 30 pruned nodes, max_depth=6
# [09:55:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [09:55:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 38 pruned nodes, max_depth=0
# [09:55:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 34 pruned nodes, max_depth=3
# [09:55:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 34 pruned nodes, max_depth=5
# [09:55:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 32 pruned nodes, max_depth=3
# [09:55:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 42 pruned nodes, max_depth=4
# [09:55:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 40 pruned nodes, max_depth=3
# [09:55:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 38 pruned nodes, max_depth=0
# [09:55:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 36 pruned nodes, max_depth=2
# [09:55:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 38 pruned nodes, max_depth=3
# [09:55:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 30 pruned nodes, max_depth=3
# [09:55:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 40 pruned nodes, max_depth=7
# [09:55:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 34 pruned nodes, max_depth=3
# [09:55:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 40 pruned nodes, max_depth=4
# [09:55:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 34 pruned nodes, max_depth=3
# [09:55:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 36 pruned nodes, max_depth=5
# [09:55:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 32 pruned nodes, max_depth=6
# [09:55:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [09:55:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [09:55:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 30 pruned nodes, max_depth=2
# [09:55:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 38 pruned nodes, max_depth=2
# [09:55:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 32 pruned nodes, max_depth=3
# [09:55:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 30 pruned nodes, max_depth=2
# [09:55:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 34 pruned nodes, max_depth=0
# [09:55:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 34 pruned nodes, max_depth=5
# [09:55:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 34 pruned nodes, max_depth=4
# [09:55:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 38 pruned nodes, max_depth=2
# [09:55:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [09:55:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 36 pruned nodes, max_depth=3
# [09:55:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 48 pruned nodes, max_depth=3
# [09:55:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 28 pruned nodes, max_depth=3
# [09:55:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=5
# [09:55:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [09:55:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [09:55:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 38 pruned nodes, max_depth=2
# [09:55:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 32 pruned nodes, max_depth=3
# [09:55:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 34 pruned nodes, max_depth=0
# [09:55:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [09:55:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 32 pruned nodes, max_depth=3
# [09:55:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 36 pruned nodes, max_depth=3
# [09:55:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 36 pruned nodes, max_depth=0
# [09:55:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 30 pruned nodes, max_depth=3
# [09:55:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [09:55:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 44 pruned nodes, max_depth=3
# [09:55:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 36 pruned nodes, max_depth=3
# [09:55:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 30 pruned nodes, max_depth=4
# [09:55:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 32 pruned nodes, max_depth=3
# [09:55:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 46 pruned nodes, max_depth=2
# [09:55:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 36 pruned nodes, max_depth=5
# [09:55:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 32 pruned nodes, max_depth=2
# [09:55:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 32 pruned nodes, max_depth=4
# [09:55:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 34 pruned nodes, max_depth=3
# [09:55:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [09:55:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 28 pruned nodes, max_depth=3
# [09:55:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [09:55:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 38 pruned nodes, max_depth=4
# [09:55:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 24 pruned nodes, max_depth=3
# [09:55:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 36 pruned nodes, max_depth=4
# [09:55:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 30 pruned nodes, max_depth=3
# [09:55:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 40 pruned nodes, max_depth=5
# [09:55:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 36 pruned nodes, max_depth=3
# [09:55:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 30 pruned nodes, max_depth=3
# [09:55:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 30 pruned nodes, max_depth=5
# [09:55:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 34 pruned nodes, max_depth=3
# [09:55:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 32 pruned nodes, max_depth=0
# [09:55:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [09:55:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 32 pruned nodes, max_depth=0
# [09:55:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 38 pruned nodes, max_depth=4
# [09:55:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 38 pruned nodes, max_depth=0
# [09:55:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 38 pruned nodes, max_depth=0
# [09:55:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 36 pruned nodes, max_depth=3
# [09:55:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 34 pruned nodes, max_depth=2
# [09:55:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 32 pruned nodes, max_depth=4
# [09:55:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 26 pruned nodes, max_depth=5
# [09:55:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [09:55:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 44 pruned nodes, max_depth=6
# [09:55:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 30 pruned nodes, max_depth=4
# [09:55:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 30 pruned nodes, max_depth=6
# [09:55:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 34 pruned nodes, max_depth=3
# [09:55:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=5
# [09:55:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [09:55:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [09:55:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 36 pruned nodes, max_depth=4
# [09:55:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 32 pruned nodes, max_depth=3
# [09:55:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 38 pruned nodes, max_depth=0
# [09:55:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0

# %%
from xgboost import plot_importance
feature_score = model.get_fscore()

# %%
feature_score = sorted(feature_score.items(), key=lambda x:x[1], reverse=True)

# %%
fs = pd.DataFrame(feature_score)

# %%
fs.to_csv("./feats_score.csv")
